# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

ins_df1 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv")

ins_df2 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv")

ins_df3 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv")

# %%
ins_df1.columns = ins_df1.columns.str.lower().str.strip().str.replace(" ", "_")
ins_df1.head()
# Out:
#   customer          st gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
ins_df2.columns = ins_df2.columns.str.lower().str.strip().str.replace(" ", "_")
ins_df2.head()
# Out:
#   customer          st gender education customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       policy_type  vehicle_class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
ins_df3.columns = ins_df3.columns.str.lower().str.strip().str.replace(" ", "_")
ins_df3.head()
# Out:
#   customer       state  customer_lifetime_value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    income  monthly_premium_auto  number_of_open_complaints    policy_type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    total_claim_amount  vehicle_class
# ...

# %%
print(ins_df1.columns)
print(ins_df2.columns)
print(ins_df3.columns)
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='str')
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='str')
# Index(['customer', 'state', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='str')

# %%
ins_df3 = ins_df3.rename(columns = {"state" : "st"})

ins_df_general = pd.concat([ins_df1, ins_df2, ins_df3], ignore_index = True)

ins_df_general
# Out:
#       customer          st gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %%
ins_df_general.isnull().all(axis=1).sum()
# Out:
# np.int64(2937)

# %%
ins_df_general = ins_df_general.dropna(how="all")

# %%
ins_df_general.isnull().sum()
# Out:
# customer                       0
# st                             0
# gender                       122
# education                      0
# customer_lifetime_value        7
# income                         0
# monthly_premium_auto           0
# number_of_open_complaints      0
# policy_type                    0
# vehicle_class                  0
# total_claim_amount             0
# dtype: int64

# %%
ins_df_general["gender"].value_counts(dropna=False)
# Out:
# gender
# F         4560
# M         4368
# NaN        122
# Male        40
# female      30
# Femal       17
# Name: count, dtype: int64

# %%
ins_df_general["gender"] = ins_df_general["gender"].replace({
    "female": "F",
    "Femal": "F",
    "Male": "M"
})

# %%
ins_df_general["gender"].value_counts(dropna=False)
# Out:
# gender
# F      4607
# M      4408
# NaN     122
# Name: count, dtype: int64

# %%
ins_df_general["customer_lifetime_value"].dtype
# Out:
# dtype('O')

# %%
ins_df_general["customer_lifetime_value"].head(10)
# Out:
# 0            NaN
# 1     697953.59%
# 2    1288743.17%
# 3     764586.18%
# 4     536307.65%
# 5     825629.78%
# 6     538089.86%
# 7     721610.03%
# 8    2412750.40%
# 9     738817.81%
# Name: customer_lifetime_value, dtype: object

# %%
has_percent = ins_df_general["customer_lifetime_value"].astype(str).str.contains("%")

ins_df_general["customer_lifetime_value"] = pd.to_numeric(
    ins_df_general["customer_lifetime_value"]
    .astype(str)
    .str.replace("%", "", regex=False),
    errors="coerce"
)

ins_df_general.loc[has_percent, "customer_lifetime_value"] /= 100

# %%
ins_df_general["customer_lifetime_value"].head(10)
# Out:
# 0           NaN
# 1     6979.5359
# 2    12887.4317
# 3     7645.8618
# 4     5363.0765
# 5     8256.2978
# 6     5380.8986
# 7     7216.1003
# 8    24127.5040
# 9     7388.1781
# Name: customer_lifetime_value, dtype: float64

# %%
ins_df_general["customer_lifetime_value"].dtype
# Out:
# dtype('float64')

# %%
ins_df_general["number_of_open_complaints"].value_counts(dropna=False)
# Out:
# number_of_open_complaints
# 0         5629
# 1/0/00    1626
# 1          765
# 2          283
# 1/1/00     247
# 3          230
# 4          119
# 1/2/00      93
# 1/3/00      60
# 5           44
# 1/4/00      29
# 1/5/00      12
# Name: count, dtype: int64

# %%
ins_df_general["number_of_open_complaints"] = ins_df_general["number_of_open_complaints"].replace({
    "1/0/00": 0,
    "1/1/00": 1,
    "1/2/00": 2,
    "1/3/00": 3,
    "1/4/00": 4,
    "1/5/00": 5
})

# %%
ins_df_general["number_of_open_complaints"] = ins_df_general["number_of_open_complaints"].astype(int)

# %%
ins_df_general["number_of_open_complaints"].value_counts()
# Out:
# number_of_open_complaints
# 0    7255
# 1    1012
# 2     376
# 3     290
# 4     148
# 5      56
# Name: count, dtype: int64

# %%
ins_df_general["st"].value_counts(dropna=False)
# Out:
# st
# California    3032
# Oregon        2601
# Arizona       1630
# Nevada         882
# Washington     768
# Cali           120
# AZ              74
# WA              30
# Name: count, dtype: int64

# %%
ins_df_general["st"] = ins_df_general["st"].replace({
    "Cali": "California",
    "AZ": "Arizona",
    "WA": "Washington"
})

# %%
ins_df_general["st"].value_counts()
# Out:
# st
# California    3152
# Oregon        2601
# Arizona       1704
# Nevada         882
# Washington     798
# Name: count, dtype: int64

# %%
ins_df_general["education"].value_counts(dropna=False)
# Out:
# education
# Bachelor                2719
# College                 2682
# High School or Below    2616
# Master                   752
# Doctor                   344
# Bachelors                 24
# Name: count, dtype: int64

# %%
ins_df_general["education"] = ins_df_general["education"].replace({
    "Bachelors": "Bachelor"
})

# %%
ins_df_general["education"].value_counts()
# Out:
# education
# Bachelor                2743
# College                 2682
# High School or Below    2616
# Master                   752
# Doctor                   344
# Name: count, dtype: int64

# %%
ins_df_general["vehicle_class"].value_counts(dropna=False)
# Out:
# vehicle_class
# Four-Door Car    4641
# Two-Door Car     1896
# SUV              1774
# Sports Car        483
# Luxury SUV        182
# Luxury Car        161
# Name: count, dtype: int64

# %%
ins_df_general["policy_type"].value_counts(dropna=False)
# Out:
# policy_type
# Personal Auto     6792
# Corporate Auto    1965
# Special Auto       380
# Name: count, dtype: int64

# %%
ins_df_general.dtypes
# Out:
# customer                         str
# st                               str
# gender                           str
# education                        str
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints      int64
# policy_type                      str
# vehicle_class                    str
# total_claim_amount           float64
# dtype: object

# %%
ins_df_general.isnull().sum()
# Out:
# customer                       0
# st                             0
# gender                       122
# education                      0
# customer_lifetime_value        7
# income                         0
# monthly_premium_auto           0
# number_of_open_complaints      0
# policy_type                    0
# vehicle_class                  0
# total_claim_amount             0
# dtype: int64

# %%
ins_df_general.duplicated().sum()
# Out:
# np.int64(3)

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
marketing_df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv")
marketing_df.head(5)
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
marketing_df["sales_channel"].value_counts()
# Out:
# sales_channel
# Agent          4121
# Branch         3022
# Call Center    2141
# Web            1626
# Name: count, dtype: int64

# %%
marketing_df[
    [
        "sales_channel",
        "customer_lifetime_value",
        "monthly_premium_auto",
        "total_claim_amount"
    ]
].head()
# Out:
#   sales_channel  customer_lifetime_value  monthly_premium_auto  \
# 0         Agent              4809.216960                    61
# 1   Call Center              2228.525238                    64
# 2   Call Center             14947.917300                   100
# 3        Branch             22332.439460                    97
# 4        Branch              9025.067525                   117
#
#    total_claim_amount
# 0          292.800000
# 1          744.924331
# 2          480.000000
# 3          484.013411
# 4          707.925645

# %%
revenue_by_channel = marketing_df.pivot_table(
    index="sales_channel",
    values="monthly_premium_auto",
    aggfunc="sum"
)

revenue_by_channel
# Out:
#                monthly_premium_auto
# sales_channel
# Agent                        386335
# Branch                       280953
# Call Center                  197970
# Web                          151511

# %%
revenue_by_channel = revenue_by_channel.round(2)
revenue_by_channel
# Out:
#                monthly_premium_auto
# sales_channel
# Agent                        386335
# Branch                       280953
# Call Center                  197970
# Web                          151511

# %%
clv_by_gender_education = marketing_df.pivot_table(
    index="gender",
    columns="education",
    values="customer_lifetime_value",
    aggfunc="mean"
)

clv_by_gender_education
# Out:
# education     Bachelor      College       Doctor  High School or Below  \
# gender
# F          7874.269478  7748.823325  7328.508916           8675.220201
# M          7703.601675  8052.459288  7415.333638           8149.687783
#
# education       Master
# gender
# F          8157.053154
# M          8168.832659

# %%
clv_by_gender_education = clv_by_gender_education.round(2)
clv_by_gender_education
# Out:
# education  Bachelor  College   Doctor  High School or Below   Master
# gender
# F           7874.27  7748.82  7328.51               8675.22  8157.05
# M           7703.60  8052.46  7415.33               8149.69  8168.83

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
